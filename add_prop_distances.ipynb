# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import scipy.stats.distributions as dist
from matplotlib.colors import LogNorm
import os

# %%
scale_factor = pd.read_parquet('/mnt/jb2854-XDrive/Physics/StudentProjects/MPhys/2022-23/IllustrisTNG-Mergers/scale_factor.parquet')

# %%
for run_id in range(600):
    try:
        path = '/home/AstroPhysics-Shared/PROJECTS/MPhys_Villforth/DATA/CNN_dir/CNN_run_%05d/' %(run_id) + 'full_subhalo_results_v2.parquet'
        if os.path.exists(path):
            results = pd.read_parquet(path)
            results['r1_prop'] = np.NaN
            for idx, row in results.iterrows():
                snap = row.SnapNum
                row['r1_prop'] = row['r1']/0.7 * scale_factor['a'][int(snap)]
                row['r2_prop'] = row['r2']/0.7 * scale_factor['a'][int(snap)]
            results.to_parquet('/home/AstroPhysics-Shared/PROJECTS/MPhys_Villforth/DATA/CNN_dir/CNN_run_%05d/' %(run_id) + 'full_subhalo_results_v2.parquet')
    except:
        print('Problem with run ', run_id)
# Out:
# Problem with run  2
# Problem with run  3
# Problem with run  4
# Problem with run  5
# Problem with run  6
# Problem with run  8
# Problem with run  9
# Problem with run  10
# Problem with run  11
# Problem with run  14
# Problem with run  15
# Problem with run  16
# Problem with run  17
# Problem with run  19
# Problem with run  20
# Problem with run  21
# Problem with run  22
# Problem with run  23
# Problem with run  24
# Problem with run  25
# Problem with run  26
# Problem with run  27
# Problem with run  28
# Problem with run  29
# Problem with run  30
# Problem with run  31
# Problem with run  35
# Problem with run  36
# Problem with run  37
# Problem with run  38
# Problem with run  39
# Problem with run  40
# Problem with run  41
# Problem with run  42
# Problem with run  43
# Problem with run  44
# Problem with run  45
# Problem with run  46
# Problem with run  47
# Problem with run  48
# Problem with run  49
# Problem with run  50
# Problem with run  51
# ...

# %%
results
# Out:
#           SFID  SnapNum  Mstellar       MBH         MDM       Mgas        SFR  \
# 0      46339.0     31.0  0.123309  0.000180    1.507623   0.215559   1.025617
# 1     295081.0     30.0  0.107888  0.000124    7.481488   0.988326   1.784852
# 2     206695.0     31.0  0.373474  0.001028   25.123503   2.943553   5.662594
# 3     248586.0     32.0  0.155156  0.000126   17.308336   2.087665   2.539999
# 4     207188.0     30.0  0.248868  0.000147   21.077393   2.368643   3.131577
# ...        ...      ...       ...       ...         ...        ...        ...
# 1210   91196.0     32.0  3.058911  0.011554  111.023613  17.163824  34.105801
# 1211  157469.0     29.0  0.297617  0.000337   27.863211   4.030433  12.850145
# 1212  105294.0     29.0  0.609654  0.000435   31.871910   7.106671  18.698193
# 1213  250856.0     30.0  0.141255  0.000229   12.795074   1.609890   3.488440
# 1214   55012.0     29.0  7.210553  0.033587  134.677917  13.231641  26.752398
#
# ...

# %%
scale_factor
# Out:
#            a
# 0   0.047514
# 1   0.062542
# 2   0.077040
# 3   0.083503
# 4   0.090937
# ..       ...
# 95  0.953722
# 96  0.967376
# 97  0.976587
# 98  0.990568
# 99  1.000000
#
# [100 rows x 1 columns]
