# %%
import sys
sys.path.append('/u/e/jb2854/Mergers_Project')
import merger_grabber as mg

# %% [markdown]
# mg

# %%
basePath = '/x/Physics/AstroPhysics/Shared-New/DATA/IllustrisTNG/TNG100-1/output'

# %%
df = mg.mergerInfoDF(basePath)

# %%
df
# Out:
#     DesSFID  DesSnap  DesMstellar       DesMDM    DesMBH      DesMgas  \
# 0         0       51    54.142384  6596.264160  0.122375  1002.770203
# 1      2448       12     0.046056    15.438217  0.000123     2.169809
# 2    113998       60    28.012173  1272.025391  0.000000   134.203110
# 3     65474       28     1.574060    80.911606  0.001080    11.390826
# 4         1       94    45.740829  1708.507446  0.177129   127.386429
# 5     65300       39    15.878142   564.987854  0.071015    46.155750
# 6     12288       24     8.113693   179.798904  0.047115    16.932064
# 7    276771       73     9.665519   299.940033  0.034092    33.623280
# 8    236545       64     6.632771   278.354553  0.022411    38.216965
# 9    227971       55     8.701754   242.877899  0.051779    13.935859
# 10    86484       32     4.765172   117.179985  0.042666    14.349347
# 11    13152       16     0.071334    18.186012  0.000100     2.567050
# ...
