# %%
import hdf52fits_mphys1 as grabber
from astropy.io import fits
from matplotlib import pyplot as plt

# %%
subhaloID = 13089
snap = 86
FITS_dir = './DF_dir/FITS_dir'

# %%
grabber.grabFITS(subhaloID, snap, FITS_dir)
# Out:
# Writing final output to HUBBLE./DF_dir/FITS_dir860013089.fits
# Time: 0:00:32.801588
# Read merger table from ./DF_dir/objectsdf_backup.parquet
# Time: 0:00:33.399840
# Constructed header
# Time: 0:00:34.128038
# ...
# wget --retry-connrefused -O ./DF_dir/HDF5_dir/86-13089-wfc3_ir_f160w-0,1.hdf5 --header="API-Key: 7441604020b774ac494f99f04f80efd7" "https://www.tng-project.org/api/TNG100-1/snapshots/86/subhalos/13089/vis.hdf5?partType=stars&partField=stellarBandObsFrame-wfc3_ir_f160w&size=20&sizeType=rHalfMassStars&method=sphMap&nPixels=1500,1500&axes=0,1&rasterPx=1100&plotStyle=edged&labelZ=False&labelSim=False&labelHalo=False&title=False&colorbars=False&scalebar=False&axes=0,1"
# ...

# %%
galaxy = fits.open('%s%02d%07d.fits' %(FITS_dir, snap, subhaloID))

# %%
galaxy.info()
# Out:
# Filename: ./DF_dir/FITS_dir860013089.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      38   ()
#   1                1 ImageHDU         9   (800, 800, 5)   float32
#   2                1 ImageHDU         9   (800, 800, 5)   float32
#   3                1 ImageHDU         9   (800, 800, 5)   float32

# %%
galaxy[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# HIERARCH subhaloID = 13089
# HIERARCH snapshot =                   86
# HIERARCH redshift =                 0.17
# HIERARCH lookback_time = 2.169
# HIERARCH partType = 'stars   '
# HIERARCH partField = 'stellarBandObsFrame-'
# HIERARCH size =                   20
# HIERARCH sizeType = 'rHalfMassStars'
# HIERARCH method = 'sphMap  '
# HIERARCH nPixels = '800,800 '
# HIERARCH axes = '0,1     '
# HIERARCH rasterPx =                 1100
# HIERARCH plotStyle = 'edged   '
# HIERARCH labelZ = 'False   '
# HIERARCH labelSim = 'False   '
# HIERARCH labelHalo = 'False   '
# HIERARCH title = 'False   '
# HIERARCH colorbars = 'False   '
# HIERARCH scalebar = 'False   '
# HIERARCH partField_0 = 'stellarBandObsFrame-sdss_u'
# HIERARCH partField_1 = 'stellarBandObsFrame-sdss_g'
# ...

# %%
angle1 = galaxy[1].data

# %%
plt.figure(figsize = (10,10))
plt.imshow(angle1[0])

# %%
galaxy_hubble = fits.open('%s%02d%07d.fits' %(FITS_dir, snap, subhaloID))
