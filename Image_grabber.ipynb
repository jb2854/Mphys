# %%
import hdf52_fits_MPhys_modified_26_10 as grabber
from astropy.io import fits
from matplotlib import pyplot as plt
from glob import glob
import time
import datetime

# %%
subhaloID = 262053
snap = 98
FITS_dir = '/mnt/jb2854-XDrive/Physics/StudentProjects/MPhys/2022-23/IllustrisTNG-Mergers/IMG_dir/FITS_dir/'

# %%
grabber.grabFITS(subhaloID, snap, FITS_dir)
# Out:
# Writing final output to /mnt/jb2854-XDrive/Physics/StudentProjects/MPhys/2022-23/IllustrisTNG-Mergers/IMG_dir/FITS_dir/sfid_{}_snap_{}_axes_{}_band_{}.fits
# Time: 0:00:00.999712
# Read merger table from /mnt/jb2854-XDrive/Physics/StudentProjects/MPhys/2022-23/IllustrisTNG-Mergers/DF_dir/objects_master_22_10_25.parquet
# Time: 0:00:01.747994
# Constructed header
# Time: 0:00:02.607385
# Opening /mnt/jb2854-XDrive/Physics/StudentProjects/MPhys/2022-23/IllustrisTNG-Mergers/IMG_dir/HDF5_dir/98-262053-wfc3_ir_f160w-0,1.hdf5
# Constructed header
# Time: 0:00:02.702644
# Opening /mnt/jb2854-XDrive/Physics/StudentProjects/MPhys/2022-23/IllustrisTNG-Mergers/IMG_dir/HDF5_dir/98-262053-wfc3_uvis_f438w-0,1.hdf5
# Constructed header
# Time: 0:00:02.788586
# ...

# %%
imgList_r = list(glob(FITS_dir + 'sfid_{}_snap_{}*.fits'.format(subhaloID, snap)))

# %%
path = imgList_r[1]

# %%
galaxy = fits.open(path)

# %%
galaxy[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# HIERARCH subhaloID = 13089
# HIERARCH snapshot =                   86
# HIERARCH redshift =                 0.17
# HIERARCH lookback_time = 2.169
# HIERARCH partType = 'stars   '
# HIERARCH partField = 'stellarBandObsFrame-'
# HIERARCH size =                    2
# HIERARCH sizeType = 'rHalfMassStars'
# HIERARCH method = 'sphMap  '
# HIERARCH nPixels = '1500,1500'
# HIERARCH axes = '0,1     '
# HIERARCH rasterPx =                 1100
# HIERARCH plotStyle = 'edged   '
# HIERARCH labelZ = 'False   '
# HIERARCH labelSim = 'False   '
# HIERARCH labelHalo = 'False   '
# HIERARCH title = 'False   '
# HIERARCH colorbars = 'False   '
# HIERARCH scalebar = 'False   '
# HIERARCH partField_0 = 'stellarBandObsFrame-wfc3_ir_f160w'
# ...

# %%
plt.imshow(galaxy[1].data[0])

# %%
import pandas as pd
objectsdf = pd.read_parquet('/mnt/jb2854-XDrive/Physics/StudentProjects/MPhys/2022-23/IllustrisTNG-Merger/DF_dir/objects_master_22_10_25.parquet')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_7898/3406800631.py in <module>
#       1 import pandas as pd
# ----> 2 objectsdf = pd.read_parquet('/mnt/jb2854-XDrive/Physics/StudentProjects/MPhys/2022-23/IllustrisTNG-Merger/DF_dir/objects_master_22_10_25.parquet')
#       3
#
# /opt/anaconda3/envs/astroconda3/lib/python3.7/site-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, **kwargs)
#     315     """
#     316     impl = get_engine(engine)
# --> 317     return impl.read(path, columns=columns, **kwargs)
#
# /opt/anaconda3/envs/astroconda3/lib/python3.7/site-packages/pandas/io/parquet.py in read(self, path, columns, **kwargs)
#     140         kwargs["use_pandas_metadata"] = True
#     141         result = self.api.parquet.read_table(
# --> 142             path, columns=columns, filesystem=fs, **kwargs
#     143         ).to_pandas()
# ...
